# %%
import gdown
import pandas as pd

# ID file dari link Google Drive
file_id = '10oJeOxJrW3FhkxL_Ee6C0ftTv99GOFsg'
url = f'https://drive.google.com/uc?id={file_id}'

# Download file menggunakan gdown
output = 'your_file.csv'
gdown.download(url, output, quiet=False)

# Baca CSV menggunakan pandas
df = pd.read_csv(output)
print(df.head())
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10oJeOxJrW3FhkxL_Ee6C0ftTv99GOFsg
# To: /content/your_file.csv
# 100%|██████████| 8.74M/8.74M [00:00<00:00, 41.9MB/s]
#    OrderID          Region         Country CustID    Customer_Name  \
# 0  SO45080       Northwest   United States  14657      JOHN THOMAS
# 1  SO45079       Southwest   United States  29255  KYLE WASHINGTON
# 2  SO45082       Australia       Australia  11455        ROSS SANZ
# 3  SO45081          Canada          Canada  26782       SETH LEWIS
# 4  SO45083  United Kingdom  United Kingdom  14947   ALEJANDRO CHEN
#
#    ProductSKU Product_Category  OrderLineItem  OrderQuantity  ProductCost  \
# 0  BK-R50B-58           Plants              1            1.0     413.1463
# 1  BK-R93R-48           Plants              1            1.0    2171.2942
# 2  BK-M82B-44           Plants              1            1.0    1898.0944
# 3  BK-R50B-44           Plants              1            1.0     413.1463
# ...

# %%
df.head(5)
# Out:
#    OrderID          Region         Country CustID    Customer_Name  \
# 0  SO45080       Northwest   United States  14657      JOHN THOMAS
# 1  SO45079       Southwest   United States  29255  KYLE WASHINGTON
# 2  SO45082       Australia       Australia  11455        ROSS SANZ
# 3  SO45081          Canada          Canada  26782       SETH LEWIS
# 4  SO45083  United Kingdom  United Kingdom  14947   ALEJANDRO CHEN
#
#    ProductSKU Product_Category  OrderLineItem  OrderQuantity  ProductCost  \
# 0  BK-R50B-58           Plants              1            1.0     413.1463
# 1  BK-R93R-48           Plants              1            1.0    2171.2942
# 2  BK-M82B-44           Plants              1            1.0    1898.0944
# 3  BK-R50B-44           Plants              1            1.0     413.1463
# 4  BK-R93R-48           Plants              1            1.0    2171.2942
#
#   ProductPrice   OrderDate AcquisitionSource      TransactionID  Fraud  \
# ...

# %%
missing_values = df.isnull().sum()

# %%
df_cleaned = df.dropna()

# %%
df_cleaned.isnull().sum()
# Out:
# OrderID              0
# Region               0
# Country              0
# CustID               0
# Customer_Name        0
# ProductSKU           0
# Product_Category     0
# OrderLineItem        0
# OrderQuantity        0
# ProductCost          0
# ProductPrice         0
# OrderDate            0
# AcquisitionSource    0
# TransactionID        0
# Fraud                0
# PaymentMethod        0
# CardType             0
# Gender               0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# OrderID               object
# Region                object
# Country               object
# CustID                object
# Customer_Name         object
# ProductSKU            object
# Product_Category      object
# OrderLineItem          int64
# OrderQuantity        float64
# ProductCost          float64
# ProductPrice          object
# OrderDate             object
# AcquisitionSource     object
# TransactionID         object
# Fraud                 object
# PaymentMethod         object
# CardType              object
# Gender                object
# dtype: object

# %%
# Convert 'ProductPrice' to numeric (float), removing any non-numeric characters
df['ProductPrice'] = pd.to_numeric(df['ProductPrice'], errors='coerce')

# Convert 'OrderDate' to datetime format
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# %%
print(df.dtypes)
# Out:
# OrderID                      object
# Region                       object
# Country                      object
# CustID                       object
# Customer_Name                object
# ProductSKU                   object
# Product_Category             object
# OrderLineItem                 int64
# OrderQuantity               float64
# ProductCost                 float64
# ProductPrice                float64
# OrderDate            datetime64[ns]
# AcquisitionSource            object
# TransactionID                object
# Fraud                        object
# PaymentMethod                object
# CardType                     object
# Gender                       object
# dtype: object

# %%
df.head(5)
# Out:
#    OrderID          Region         Country CustID    Customer_Name  \
# 0  SO45080       Northwest   United States  14657      JOHN THOMAS
# 1  SO45079       Southwest   United States  29255  KYLE WASHINGTON
# 2  SO45082       Australia       Australia  11455        ROSS SANZ
# 3  SO45081          Canada          Canada  26782       SETH LEWIS
# 4  SO45083  United Kingdom  United Kingdom  14947   ALEJANDRO CHEN
#
#    ProductSKU Product_Category  OrderLineItem  OrderQuantity  ProductCost  \
# 0  BK-R50B-58           Plants              1            1.0     413.1463
# 1  BK-R93R-48           Plants              1            1.0    2171.2942
# 2  BK-M82B-44           Plants              1            1.0    1898.0944
# 3  BK-R50B-44           Plants              1            1.0     413.1463
# 4  BK-R93R-48           Plants              1            1.0    2171.2942
#
#    ProductPrice  OrderDate AcquisitionSource      TransactionID  Fraud  \
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1RVw1rYX43PKiWjcNDxh0b0RY8UOh5CQbly_Btd822zE#gid=0
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py:31: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return frame.applymap(_clean_val).replace({np.nan: None})
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1RVw1rYX43PKiWjcNDxh0b0RY8UOh5CQbly_Btd822zE#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
